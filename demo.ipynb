# %% [markdown]
# # Queue-Priority L3 Simulator Demo
# This notebook demonstrates event-driven queue tracking. It shows how target orders wait in line and fill dynamically based on trade size allocations.

# %%
import subprocess

print("Compiling Rust queue simulator...")
subprocess.run(["cargo", "build", "--release"], check=True)

print("Running backtest replay...")
result = subprocess.run(["cargo", "run", "--release"], capture_output=True, text=True)
print(result.stdout)
